# %% [markdown]
# загружаю файл эксель

# %%
#from google.colab import files
#upload=files.upload()

# %% [markdown]
# чтение экслея

# %%
# !pip install -q xlrd

# %%
#import io

# %% [markdown]
# загружаю пандас

# %%
import pandas as pd
import numpy as np

# %%
#test = pd.read_excel('Тестовое задание.xlsx')

# %% [markdown]
# загружаю в переменные названия листов с файла эксель

# %%
snamek = "кандидаты"
snameks = "статусы кандидатов"
snamerpl = "размещения на рекламных площадк"
snamesrg = "справочник регионов"
snamebud = "бюджеты"

# %% [markdown]
# создаю переменные с таблицами с листов эксель

# %%
tsk = pd.read_excel('Тестовое задание.xlsx', snamek)
tsks = pd.read_excel('Тестовое задание.xlsx', snameks)
tsrpl = pd.read_excel('Тестовое задание.xlsx', snamerpl)
tssrg = pd.read_excel('Тестовое задание.xlsx', snamesrg)
tsbud = pd.read_excel('Тестовое задание.xlsx', snamebud)

# %%
tsk.head(3)
# Out:
#    Кандидат    Источник                      Регион
# 0         4  Источник 1              Омская область
# 1         5  Источник 1  Ханты-Мансийский АО - Югра
# 2         7  Источник 1     Республика Башкортостан

# %%
tsks.head(3)
# Out:
#    Кандидат Статус кандидата    Дата и время статуса
# 0        22         Оформлен 2022-10-13 06:23:07.497
# 1        56         Оформлен 2022-07-15 08:00:02.930
# 2        63         Оформлен 2022-12-09 13:45:34.572

# %%
tsrpl.head(3)
# Out:
#   Населенный пункт Дата публикации    Источник
# 0          Иркутск      2022-05-04  Источник 1
# 1        Краснодар      2022-05-04  Источник 1
# 2       Красноярск      2022-05-04  Источник 1

# %%
tssrg.head(3)
# Out:
#                     Регион Населенный пункт
# 0  Республика Башкортостан   1-е Туркменево
# 1        Красноярский край        Абалаково
# 2        Красноярский край             Абан

# %%
tsbud.head(3)
# Out:
#      Источник Период бюджета от Период бюджета до  Бюджет
# 0  Источник 1        2022-05-01        2022-05-31  300000
# 1  Источник 1        2022-06-01        2022-06-30  300000
# 2  Источник 1        2022-07-01        2022-07-31       0

# %% [markdown]
# создаю из двух таблиц выше одну по общему столбцу "Кандидат"

# %%
tskskom = tsks.set_index('Кандидат').join(tsk.set_index('Кандидат'))

# %% [markdown]
# создаю столбец год и месяц year_month и столбец номер месяца MonthNum из данных столбца "Дата и время статуса"

# %%
tskskom["year_month"] = tskskom["Дата и время статуса"].dt.to_period("M")
tskskom['MonthNum'] = tskskom["Дата и время статуса"].dt.month

# %% [markdown]
# удаляю ненужный столбец "Дата и время статуса"

# %%
tskskom.drop(['Дата и время статуса'], axis=1, inplace=True)

# %%
tskskom
# Out:
#          Статус кандидата    Источник                      Регион year_month  \
# Кандидат
# 4                   Новый  Источник 1              Омская область    2022-07
# 5                   Новый  Источник 1  Ханты-Мансийский АО - Югра    2022-06
# 7                   Новый  Источник 1     Республика Башкортостан    2022-06
# 8                   Новый  Источник 1           Ямало-Ненецкий АО    2022-06
# 9                   Новый  Источник 1          Московская область    2023-02
# ...                   ...         ...                         ...        ...
# 7586                Новый  Источник 1          Московская область    2023-02
# 7587                Новый  Источник 1           Иркутская область    2023-02
# 7588                Новый  Источник 1  Ханты-Мансийский АО - Югра    2023-02
# 7589                Новый  Источник 1           Ямало-Ненецкий АО    2023-02
# 7591                Новый  Источник 1          Московская область    2023-02
#
#           MonthNum
# Кандидат
# ...

# %% [markdown]
# посмотрим сколько привлекли кандидатов разные источники

# %%
tskskom.groupby('Источник').count()
# Out:
#             Статус кандидата  Регион  year_month  MonthNum
# Источник
# Источник 1              4446    4446        4446      4446
# Источник 2              1069    1069        1069      1069

# %% [markdown]
# посмотрим какие регионы сортирвка по алфавиту

# %%
a=tskskom['Регион'].unique()
a=pd.DataFrame(a)
a.sort_values(0)
# Out:
#                             0
# 5           Иркутская область
# 8          Краснодарский край
# 7           Красноярский край
# 6       Ленинградская область
# 4          Московская область
# 0              Омская область
# 2     Республика Башкортостан
# 1  Ханты-Мансийский АО - Югра
# 3           Ямало-Ненецкий АО

# %% [markdown]
# пример с иркутской областью

# %%
tskskomi = tskskom.loc[tskskom['Регион'] == 'Иркутская область']
tskskomi.head(3)
# Out:
#          Статус кандидата    Источник             Регион year_month  MonthNum
# Кандидат
# 20                  Новый  Источник 2  Иркутская область    2023-01         1
# 31                  Новый  Источник 1  Иркутская область    2023-01         1
# 35                  Новый  Источник 1  Иркутская область    2023-01         1

# %%
tskskomi.groupby('Источник').count()
# Out:
#             Статус кандидата  Регион  year_month  MonthNum
# Источник
# Источник 1               396     396         396       396
# Источник 2               136     136         136       136

# %% [markdown]
# пример с Республика Башкортостан

# %%
tskskomb = tskskom.loc[tskskom['Регион'] == 'Республика Башкортостан']
tskskomb.head(3)
# Out:
#          Статус кандидата    Источник                   Регион year_month  \
# Кандидат
# 7                   Новый  Источник 1  Республика Башкортостан    2022-06
# 24                  Новый  Источник 1  Республика Башкортостан    2022-10
# 25                  Новый  Источник 2  Республика Башкортостан    2022-09
#
#           MonthNum
# Кандидат
# 7                6
# 24              10
# 25               9

# %%
tskskomb.groupby('Источник').count()
# Out:
#             Статус кандидата  Регион  year_month  MonthNum
# Источник
# Источник 1              1369    1369        1369      1369
# Источник 2               152     152         152       152

# %% [markdown]
# создаю таблицу, в которой отобраны только 'Источник 1'

# %%
tskskom1 = tskskom.loc[tskskom['Источник'] == 'Источник 1']
tskskom1
# Out:
#          Статус кандидата    Источник                      Регион year_month  \
# Кандидат
# 4                   Новый  Источник 1              Омская область    2022-07
# 5                   Новый  Источник 1  Ханты-Мансийский АО - Югра    2022-06
# 7                   Новый  Источник 1     Республика Башкортостан    2022-06
# 8                   Новый  Источник 1           Ямало-Ненецкий АО    2022-06
# 9                   Новый  Источник 1          Московская область    2023-02
# ...                   ...         ...                         ...        ...
# 7586                Новый  Источник 1          Московская область    2023-02
# 7587                Новый  Источник 1           Иркутская область    2023-02
# 7588                Новый  Источник 1  Ханты-Мансийский АО - Югра    2023-02
# 7589                Новый  Источник 1           Ямало-Ненецкий АО    2023-02
# 7591                Новый  Источник 1          Московская область    2023-02
#
#           MonthNum
# Кандидат
# ...

# %%
tskskom1.groupby('Статус кандидата').count()
# Out:
#                   Источник  Регион  year_month  MonthNum
# Статус кандидата
# Новый                 4083    4083        4083      4083
# Оформлен               363     363         363       363

# %% [markdown]
# функция суммирования по месяцам при статусе "Оформлен"

# %%
of1 = tskskom1.groupby('year_month')['Статус кандидата'].apply ( lambda x: (x=='Оформлен'). sum ()). reset_index(name='count_of1')

# %% [markdown]
# функция суммирования по месяцам при статусе "Новый"

# %%
n1 = tskskom1.groupby('year_month')['Статус кандидата'].apply ( lambda x: (x=='Новый'). sum ()). reset_index(name='count_n1')

# %% [markdown]
# готовим таблицу для сведения из 1 Источника

# %%
sv1 = of1.set_index('year_month').join(n1.set_index('year_month'))

# %%
sv1.reset_index(inplace=True)

# %% [markdown]
# тоже самое создаю для "Источник 2"

# %%
tskskom2 = tskskom.loc[tskskom['Источник'] == 'Источник 2']
tskskom2
# Out:
#          Статус кандидата    Источник                      Регион year_month  \
# Кандидат
# 11                  Новый  Источник 2           Ямало-Ненецкий АО    2022-08
# 20                  Новый  Источник 2           Иркутская область    2023-01
# 25                  Новый  Источник 2     Республика Башкортостан    2022-09
# 59                  Новый  Источник 2           Красноярский край    2022-09
# 86                  Новый  Источник 2          Московская область    2022-09
# ...                   ...         ...                         ...        ...
# 7555                Новый  Источник 2           Иркутская область    2023-02
# 7557                Новый  Источник 2          Краснодарский край    2023-02
# 7558                Новый  Источник 2  Ханты-Мансийский АО - Югра    2023-02
# 7584                Новый  Источник 2           Красноярский край    2023-02
# 7585                Новый  Источник 2           Красноярский край    2023-02
#
#           MonthNum
# Кандидат
# ...

# %%
tskskom2.groupby('Статус кандидата').count()
# Out:
#                   Источник  Регион  year_month  MonthNum
# Статус кандидата
# Новый                 1036    1036        1036      1036
# Оформлен                33      33          33        33

# %%
of2 = tskskom2.groupby('year_month')['Статус кандидата'].apply ( lambda x: (x=='Оформлен'). sum ()). reset_index(name='count_of2')

# %%
n2 = tskskom2.groupby('year_month')['Статус кандидата'].apply ( lambda x: (x=='Новый'). sum ()). reset_index(name='count_n2')

# %% [markdown]
# готовим таблицу для сведения из 2 Источника

# %%
sv2 = of2.set_index('year_month').join(n2.set_index('year_month'))

# %%
sv2.reset_index(inplace=True)

# %% [markdown]
# создаю сводную таблицу для двух источников

# %%
sv = sv1.set_index('year_month').join(sv2.set_index('year_month'))
sv
# Out:
#             count_of1  count_n1  count_of2  count_n2
# year_month
# 2022-05            13       583          0        39
# 2022-06            24       476          1        41
# 2022-07            40       263          0        56
# 2022-08            42       293          1        84
# 2022-09            47       350          6       119
# 2022-10            34       291          6        98
# 2022-11            37       321          4       107
# 2022-12            45       355          5       108
# 2023-01            40       675          6       244
# 2023-02            41       476          4       140

# %%
tsks.groupby('Статус кандидата').count()
# Out:
#                   Кандидат  Дата и время статуса
# Статус кандидата
# Новый                 5119                  5119
# Оформлен               396                   396

# %%
tsks["year_month"] = tsks["Дата и время статуса"].dt.to_period("M")
tsks['MonthNum'] = tsks["Дата и время статуса"].dt.month

# %%
tsks['MonthNum'] = tsks["Дата и время статуса"].dt.month

# %%
b = tsks.groupby(['year_month','Статус кандидата'])
b.first()
# Out:
#                              Кандидат    Дата и время статуса  MonthNum
# year_month Статус кандидата
# 2022-05    Новый                   14 2022-05-25 14:38:59.310         5
#            Оформлен               123 2022-05-19 11:57:35.026         5
# 2022-06    Новый                    5 2022-06-03 08:24:04.934         6
#            Оформлен               218 2022-06-09 14:09:01.841         6
# 2022-07    Новый                    4 2022-07-08 15:00:26.217         7
#            Оформлен                56 2022-07-15 08:00:02.930         7
# 2022-08    Новый                   11 2022-08-29 12:56:34.241         8
#            Оформлен                76 2022-08-01 14:34:30.362         8
# 2022-09    Новый                   25 2022-09-28 08:06:28.000         9
#            Оформлен               293 2022-09-29 07:17:59.097         9
# 2022-10    Новый                   24 2022-10-24 09:05:00.148        10
#            Оформлен                22 2022-10-13 06:23:07.497        10
# ...

# %%
tsks['YearNum'] = tsks["Дата и время статуса"].dt.year

# %%
tsks.groupby('year_month').count()
# Out:
#             Кандидат  Статус кандидата  Дата и время статуса  MonthNum  \
# year_month
# 2022-05          635               635                   635       635
# 2022-06          542               542                   542       542
# 2022-07          359               359                   359       359
# 2022-08          420               420                   420       420
# 2022-09          522               522                   522       522
# 2022-10          429               429                   429       429
# 2022-11          469               469                   469       469
# 2022-12          513               513                   513       513
# 2023-01          965               965                   965       965
# 2023-02          661               661                   661       661
#
#             YearNum
# year_month
# 2022-05         635
# 2022-06         542
# 2022-07         359
# 2022-08         420
# 2022-09         522
# 2022-10         429
# ...

# %%
tsks.drop(['Дата и время статуса'], axis=1, inplace=True)

# %%
tsks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5515 entries, 0 to 5514
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Кандидат          5515 non-null   int64
#  1   Статус кандидата  5515 non-null   object
#  2   year_month        5515 non-null   period[M]
#  3   MonthNum          5515 non-null   int64
#  4   YearNum           5515 non-null   int64
# dtypes: int64(3), object(1), period[M](1)
# memory usage: 215.6+ KB

# %%
tssrg
# Out:
#                        Регион           Населенный пункт
# 0     Республика Башкортостан             1-е Туркменево
# 1           Красноярский край                  Абалаково
# 2           Красноярский край                       Абан
# 3     Республика Башкортостан                   Абзаково
# 4          Краснодарский край                     Абинск
# ...                       ...                        ...
# 1991       Краснодарский край                Ярославская
# 1992        Ямало-Ненецкий АО                    Яр-Сале
# 1993        Ямало-Ненецкий АО  Яр-Сале (Ямальский район)
# 1994       Краснодарский край                   Ясенская
# 1995       Московская область                     Яхрома
#
# [1996 rows x 2 columns]

# %% [markdown]
# соединим две таблицы, чтоб выяснить в каких регионах сколько релкамы из какого источника

# %%
tsrplrg = tssrg.set_index('Населенный пункт').join(tsrpl.set_index('Населенный пункт'))

# %%
#tsrplrg=tsrplrg.dropna()

# %%
tsrplrg
# Out:
#                                    Регион         Дата публикации    Источник
# Населенный пункт
# 1-е Туркменево    Республика Башкортостан                     NaT         NaN
# Абалаково               Красноярский край                     NaT         NaN
# Абан                    Красноярский край                     NaT         NaN
# Абзаково          Республика Башкортостан                     NaT         NaN
# Абинск                 Краснодарский край 2023-01-27 07:59:06.489  Источник 2
# ...                                   ...                     ...         ...
# Ярополец               Московская область                     NaT         NaN
# Ярославская            Краснодарский край                     NaT         NaN
# Ясенская               Краснодарский край                     NaT         NaN
# Яхрома                 Московская область                     NaT         NaN
# коротчаево              Ямало-Ненецкий АО                     NaT         NaN
#
# ...

# %% [markdown]
# устанавливаем месяц и год

# %%
tsrplrg["year_month_pl"] = tsrplrg["Дата публикации"].dt.to_period("M")

# %% [markdown]
# удаляем ненужный столбец с полной датой и временем публикации

# %%
tsrplrg.drop(['Дата публикации'], axis=1, inplace=True)

# %% [markdown]
# сбрасываем индекс со столбца Населенный пункт, чтоб потом его удалить

# %%
tsrplrg.reset_index(inplace=True)

# %%
tsrplrg.drop(['Населенный пункт'], axis=1, inplace=True)

# %% [markdown]
# удалим пропуски, они вызваны тем, что не в каждом городе было привлечение кандидатов

# %%
tsrplrg = tsrplrg.dropna(subset=['Источник'])

# %%
tsrplrg.head(3)
# Out:
#                Регион    Источник year_month_pl
# 4  Краснодарский край  Источник 2       2023-01
# 5  Краснодарский край  Источник 2       2023-01
# 6  Краснодарский край  Источник 2       2023-02

# %%
d=tsrplrg['year_month_pl'].unique()
d=pd.DataFrame(d)
d.sort_values(0)
# Out:
#           0
# 10  2022-05
# 3   2022-06
# 2   2022-07
# 6   2022-08
# 4   2022-09
# 8   2022-10
# 5   2022-11
# 7   2022-12
# 0   2023-01
# 1   2023-02
# 9   2023-03

# %%
#возможный способ выввести группировку
#b = tsrplrg.groupby(['year_month_pl','Источник','Регион'])
#b.first()

# %%
tsbud
# Out:
#       Источник Период бюджета от Период бюджета до  Бюджет
# 0   Источник 1        2022-05-01        2022-05-31  300000
# 1   Источник 1        2022-06-01        2022-06-30  300000
# 2   Источник 1        2022-07-01        2022-07-31       0
# 3   Источник 1        2022-08-01        2022-08-31       0
# 4   Источник 1        2022-09-01        2022-09-30  300000
# 5   Источник 1        2022-10-01        2022-10-31  300000
# 6   Источник 1        2022-11-01        2022-11-30  300000
# 7   Источник 1        2022-12-01        2022-12-31  300000
# 8   Источник 2        2022-05-01        2022-05-31  250000
# 9   Источник 2        2022-06-01        2022-06-30  200000
# 10  Источник 2        2022-07-01        2022-07-31  300000
# 11  Источник 2        2022-08-01        2022-08-31  450000
# 12  Источник 2        2022-09-01        2022-09-30  250000
# 13  Источник 2        2022-10-01        2022-10-31  200000
# 14  Источник 2        2022-11-01        2022-11-30       0
# ...

# %%
tsbud2 = tsbud.loc[8:16]
tsbud2.reset_index(inplace=True)

# %%
tsbud2
# Out:
#    index    Источник Период бюджета от Период бюджета до  Бюджет
# 0      8  Источник 2        2022-05-01        2022-05-31  250000
# 1      9  Источник 2        2022-06-01        2022-06-30  200000
# 2     10  Источник 2        2022-07-01        2022-07-31  300000
# 3     11  Источник 2        2022-08-01        2022-08-31  450000
# 4     12  Источник 2        2022-09-01        2022-09-30  250000
# 5     13  Источник 2        2022-10-01        2022-10-31  200000
# 6     14  Источник 2        2022-11-01        2022-11-30       0
# 7     15  Источник 2        2022-12-01        2022-12-31       0

# %% [markdown]
# создаем таблицу для подсчета искомых значений

# %%
sv.reset_index(inplace=True)

# %%
sv = sv.assign(Bud1 = tsbud['Бюджет'].loc[0:7])
sv
# Out:
#   year_month  count_of1  count_n1  count_of2  count_n2      Bud1
# 0    2022-05         13       583          0        39  300000.0
# 1    2022-06         24       476          1        41  300000.0
# 2    2022-07         40       263          0        56       0.0
# 3    2022-08         42       293          1        84       0.0
# 4    2022-09         47       350          6       119  300000.0
# 5    2022-10         34       291          6        98  300000.0
# 6    2022-11         37       321          4       107  300000.0
# 7    2022-12         45       355          5       108  300000.0
# 8    2023-01         40       675          6       244       NaN
# 9    2023-02         41       476          4       140       NaN

# %%
sv = sv.assign(Bud2 = tsbud2['Бюджет'].loc[0:8])

# %%
#sv.drop(['index'], axis=1, inplace=True)

# %% [markdown]
# расчет затрат на привечение одного оформленного по истоникам и месяцам

# %%
sv['ст_оф1']=(sv['Bud1']/sv['count_of1']).round(2)

# %%
sv['ст_оф2']=(sv['Bud2']/sv['count_of2']).round(2)

# %% [markdown]
# расчет затрат на одного нового по источникам и месяцам

# %%
sv['ст_н1']=(sv['Bud1']/sv['count_n1']).round(2)

# %%
sv['ст_н2']=(sv['Bud2']/sv['count_n2']).round(2)

# %% [markdown]
# оформление итоговой таблицы:удаление пропусков (месяцы 23 года), приведение столбца к числовым занчениям и замена inf на 0 для суммирования занчений

# %%
sv = sv.dropna(subset=['ст_н2'])

# %%
sv['ст_оф2'] = pd.to_numeric(sv['ст_оф2'])

# %%
sv.replace([np.inf], 0 , inplace= True )

# %% [markdown]
# итоги 22 года

# %%
sv.loc['Total',:] = sv.sum(axis=0)
sv.loc[:,'Total'] = sv.sum(axis=1)
# Out:
# <ipython-input-151-b9e5a14d3ecf>:1: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sv.loc['Total',:] = sv.sum(axis=0)
# <ipython-input-151-b9e5a14d3ecf>:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   sv.loc[:,'Total'] = sv.sum(axis=1)

# %%
sv.drop(['Total'], axis=1, inplace=True)

# %%
sv
# Out:
#       year_month  count_of1  count_n1  count_of2  count_n2       Bud1  \
# 0        2022-05       13.0     583.0        0.0      39.0   300000.0
# 1        2022-06       24.0     476.0        1.0      41.0   300000.0
# 2        2022-07       40.0     263.0        0.0      56.0        0.0
# 3        2022-08       42.0     293.0        1.0      84.0        0.0
# 4        2022-09       47.0     350.0        6.0     119.0   300000.0
# 5        2022-10       34.0     291.0        6.0      98.0   300000.0
# 6        2022-11       37.0     321.0        4.0     107.0   300000.0
# 7        2022-12       45.0     355.0        5.0     108.0   300000.0
# Total        NaT      282.0    2932.0       23.0     652.0  1800000.0
#
#             Bud2    ст_оф1     ст_оф2    ст_н1     ст_н2
# 0       250000.0  23076.92       0.00   514.58   6410.26
# 1       200000.0  12500.00  200000.00   630.25   4878.05
# 2       300000.0      0.00       0.00     0.00   5357.14
# ...

# %% [markdown]
# записываем таблицу в эксель

# %%
pip install openpyxl

# %%
sv.to_excel (r'E:\mydata.xlsx')
